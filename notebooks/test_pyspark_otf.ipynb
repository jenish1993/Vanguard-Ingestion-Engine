# %% [markdown]
# Test Code on the fly to track errors and resolve it.

# %%
from pyspark.sql import SparkSession

# %%
# create a test session.
session = SparkSession.builder \
            .appName("testApp") \
            .master("local[*]") \
            .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/25 15:06:27 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/05/25 15:06:27 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
